# %% [markdown]
# Experiment 0:
# introduction to python

# %%
# Amod Marathe PRN-25070123073
print("Amod Marathe")
print(2)
print([1,2,5])
# Out:
# Amod Marathe
# 2
# [1, 2, 5]

# %%
a=[1 ,2,5]
print([1,2,5])
print(a)
# Out:
# [1, 2, 5]
# [1, 2, 5]

# %%
x = 2
y=[1,2,5]
z= "amod marathe"
print(x)
print(y)
print(z)
# Out:
# 2
# [1, 2, 5]
# amod marathe

# %%
from abc import abstractmethod
name= "amod"
number=2
matrix=[1,2,3]
print(name,number,matrix)
# Out:
# amod 2 [1, 2, 3]

# %%
from abc import abstractmethod
name= "amod"
number=2
matrix=[1,2,3]
print(name,number,matrix,sep="\n")
# Out:
# amod
# 2
# [1, 2, 3]
